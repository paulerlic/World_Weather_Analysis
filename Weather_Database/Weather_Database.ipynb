# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add latitudes and longitudes to list
coordinates = list(lat_lngs)

# %%
# Use citipy module to determine nearest city based on latitude and longitude
from citipy import citipy

# %%
# Create list for holding cities
cities = []
# Identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If city is unique, then add to cities list
    if city not in cities:
        cities.append(city)
# Print city count to confirm sufficient count
len(cities)
# Out:
# 775

# %%
# Import requests library
import requests

# Import API key
from config import weather_api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import time library and datetime module from datetime library 
import time
from datetime import datetime

# %%
# Create empty list to hold weather data
city_data = []
# Print beginning of logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all cities in list
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to record count
    record_count += 1
    
# Run API request for each city
    try:
        # Parse JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append city information into city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If error experienced, skip city
    except: 
        print("City not found. Skipping...")
        pass

# Indicate Data Loading complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | peto
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | dikson
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | avarua
# Processing Record 9 of Set 1 | hervey bay
# Processing Record 10 of Set 1 | cidreira
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 1 | qui nhon
# Processing Record 14 of Set 1 | ermoupolis
# Processing Record 15 of Set 1 | kruisfontein
# Processing Record 16 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 1 | alta floresta
# Processing Record 18 of Set 1 | camacari
# Processing Record 19 of Set 1 | thompson
# Processing Record 20 of Set 1 | mar del plata
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | tuktoyaktuk
# Processing Record 23 of Set 1 | oga
# Processing Record 24 of Set 1 | bambous virieux
# Processing Record 25 of Set 1 | fort nelson
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | camacha
# Processing Record 28 of Set 1 | port elizabeth
# Processing Record 29 of Set 1 | toktogul
# Processing Record 30 of Set 1 | raga
# Processing Record 31 of Set 1 | tessalit
# Processing Record 32 of Set 1 | liloy
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | constitucion
# Processing Record 37 of Set 1 | kununurra
# Processing Record 38 of Set 1 | upernavik
# Processing Record 39 of Set 1 | didi lilo
# Processing Record 40 of Set 1 | tasiilaq
# Processing Record 41 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 1 | lilongwe
# Processing Record 43 of Set 1 | narsaq
# Processing Record 44 of Set 1 | los llanos de aridane
# Processing Record 45 of Set 1 | atuona
# Processing Record 46 of Set 1 | geraldton
# Processing Record 47 of Set 1 | saskylakh
# Processing Record 48 of Set 1 | vila
# Processing Record 49 of Set 1 | ostrovnoy
# Processing Record 50 of Set 1 | colares
# Processing Record 1 of Set 2 | coquimbo
# Processing Record 2 of Set 2 | viedma
# Processing Record 3 of Set 2 | longyearbyen
# Processing Record 4 of Set 2 | yellowknife
# Processing Record 5 of Set 2 | bredasdorp
# Processing Record 6 of Set 2 | cherskiy
# Processing Record 7 of Set 2 | kloulklubed
# Processing Record 8 of Set 2 | faanui
# Processing Record 9 of Set 2 | jalu
# Processing Record 10 of Set 2 | bethel
# Processing Record 11 of Set 2 | arraial do cabo
# Processing Record 12 of Set 2 | padang
# Processing Record 13 of Set 2 | kodiak
# Processing Record 14 of Set 2 | dingle
# Processing Record 15 of Set 2 | san patricio
# Processing Record 16 of Set 2 | georgetown
# Processing Record 17 of Set 2 | pierre
# Processing Record 18 of Set 2 | safaga
# Processing Record 19 of Set 2 | lebu
# Processing Record 20 of Set 2 | dubbo
# Processing Record 21 of Set 2 | chokurdakh
# Processing Record 22 of Set 2 | tuggurt
# City not found. Skipping...
# Processing Record 23 of Set 2 | saint-augustin
# Processing Record 24 of Set 2 | mahebourg
# Processing Record 25 of Set 2 | rush
# Processing Record 26 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 2 | linjiang
# Processing Record 28 of Set 2 | bratsk
# Processing Record 29 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 2 | carnarvon
# Processing Record 31 of Set 2 | rawson
# Processing Record 32 of Set 2 | jamestown
# Processing Record 33 of Set 2 | mount isa
# Processing Record 34 of Set 2 | moron
# Processing Record 35 of Set 2 | tiksi
# Processing Record 36 of Set 2 | sitka
# Processing Record 37 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 2 | borzya
# Processing Record 39 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 2 | westlock
# Processing Record 41 of Set 2 | baixa grande
# Processing Record 42 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 43 of Set 2 | new norfolk
# Processing Record 44 of Set 2 | port alfred
# Processing Record 45 of Set 2 | mataura
# Processing Record 46 of Set 2 | hilo
# Processing Record 47 of Set 2 | finschhafen
# Processing Record 48 of Set 2 | san luis
# Processing Record 49 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 2 | betare oya
# Processing Record 1 of Set 3 | hazorasp
# Processing Record 2 of Set 3 | nikolskoye
# Processing Record 3 of Set 3 | nome
# Processing Record 4 of Set 3 | saldanha
# Processing Record 5 of Set 3 | lubumbashi
# Processing Record 6 of Set 3 | pocoes
# Processing Record 7 of Set 3 | hithadhoo
# Processing Record 8 of Set 3 | yar-sale
# Processing Record 9 of Set 3 | kindia
# Processing Record 10 of Set 3 | champerico
# Processing Record 11 of Set 3 | celestun
# Processing Record 12 of Set 3 | vrede
# Processing Record 13 of Set 3 | qaanaaq
# Processing Record 14 of Set 3 | tamandare
# Processing Record 15 of Set 3 | tara
# Processing Record 16 of Set 3 | apatity
# Processing Record 17 of Set 3 | lydenburg
# Processing Record 18 of Set 3 | itarema
# Processing Record 19 of Set 3 | kapaa
# Processing Record 20 of Set 3 | upata
# Processing Record 21 of Set 3 | torbay
# Processing Record 22 of Set 3 | bengkulu
# Processing Record 23 of Set 3 | walvis bay
# Processing Record 24 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 3 | omsukchan
# Processing Record 26 of Set 3 | vestmannaeyjar
# Processing Record 27 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 28 of Set 3 | husavik
# Processing Record 29 of Set 3 | revelstoke
# Processing Record 30 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 3 | port blair
# Processing Record 32 of Set 3 | codrington
# Processing Record 33 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 3 | iroquois falls
# Processing Record 35 of Set 3 | airai
# Processing Record 36 of Set 3 | castro
# Processing Record 37 of Set 3 | presidencia roque saenz pena
# Processing Record 38 of Set 3 | mogadishu
# Processing Record 39 of Set 3 | souillac
# Processing Record 40 of Set 3 | basoda
# Processing Record 41 of Set 3 | bandundu
# Processing Record 42 of Set 3 | secunda
# Processing Record 43 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 3 | hellin
# Processing Record 45 of Set 3 | mount gambier
# Processing Record 46 of Set 3 | pevek
# Processing Record 47 of Set 3 | half moon bay
# Processing Record 48 of Set 3 | buala
# Processing Record 49 of Set 3 | maraba
# Processing Record 50 of Set 3 | cabo san lucas
# Processing Record 1 of Set 4 | oranjemund
# Processing Record 2 of Set 4 | melo
# Processing Record 3 of Set 4 | synya
# Processing Record 4 of Set 4 | terrace
# Processing Record 5 of Set 4 | la ronge
# Processing Record 6 of Set 4 | nizwa
# Processing Record 7 of Set 4 | lata
# Processing Record 8 of Set 4 | big spring
# Processing Record 9 of Set 4 | ponto novo
# Processing Record 10 of Set 4 | busia
# Processing Record 11 of Set 4 | awbari
# Processing Record 12 of Set 4 | khatanga
# Processing Record 13 of Set 4 | provideniya
# Processing Record 14 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 15 of Set 4 | iqaluit
# Processing Record 16 of Set 4 | visby
# Processing Record 17 of Set 4 | ratnagiri
# Processing Record 18 of Set 4 | agadez
# Processing Record 19 of Set 4 | leningradskiy
# Processing Record 20 of Set 4 | vila velha
# Processing Record 21 of Set 4 | gimli
# Processing Record 22 of Set 4 | norman wells
# Processing Record 23 of Set 4 | belaya gora
# Processing Record 24 of Set 4 | vaini
# Processing Record 25 of Set 4 | wanning
# Processing Record 26 of Set 4 | la crosse
# Processing Record 27 of Set 4 | wangqing
# Processing Record 28 of Set 4 | sharanga
# Processing Record 29 of Set 4 | santiago
# Processing Record 30 of Set 4 | tekeli
# Processing Record 31 of Set 4 | brive-la-gaillarde
# Processing Record 32 of Set 4 | saint-philippe
# Processing Record 33 of Set 4 | butaritari
# Processing Record 34 of Set 4 | matsanga
# City not found. Skipping...
# Processing Record 35 of Set 4 | fiche
# Processing Record 36 of Set 4 | kaitangata
# Processing Record 37 of Set 4 | road town
# Processing Record 38 of Set 4 | brae
# Processing Record 39 of Set 4 | luderitz
# Processing Record 40 of Set 4 | arman
# Processing Record 41 of Set 4 | taltal
# Processing Record 42 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 4 | avera
# Processing Record 44 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 45 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 46 of Set 4 | arkhangelsk
# Processing Record 47 of Set 4 | singaparna
# Processing Record 48 of Set 4 | nelson bay
# Processing Record 49 of Set 4 | ponta do sol
# Processing Record 50 of Set 4 | pandan niog
# Processing Record 1 of Set 5 | bria
# Processing Record 2 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 3 of Set 5 | honiara
# Processing Record 4 of Set 5 | saint george
# Processing Record 5 of Set 5 | kangaatsiaq
# Processing Record 6 of Set 5 | henties bay
# Processing Record 7 of Set 5 | palafrugell
# Processing Record 8 of Set 5 | korem
# Processing Record 9 of Set 5 | faya
# Processing Record 10 of Set 5 | abu kamal
# Processing Record 11 of Set 5 | xingcheng
# Processing Record 12 of Set 5 | jaciara
# Processing Record 13 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 5 | tabou
# Processing Record 15 of Set 5 | balsas
# Processing Record 16 of Set 5 | gobabis
# Processing Record 17 of Set 5 | nouadhibou
# Processing Record 18 of Set 5 | parrita
# Processing Record 19 of Set 5 | east london
# Processing Record 20 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 5 | byron bay
# Processing Record 22 of Set 5 | vrangel
# Processing Record 23 of Set 5 | machilipatnam
# Processing Record 24 of Set 5 | victoria
# Processing Record 25 of Set 5 | eyl
# Processing Record 26 of Set 5 | ilulissat
# Processing Record 27 of Set 5 | dakoro
# Processing Record 28 of Set 5 | baringo
# Processing Record 29 of Set 5 | usevya
# Processing Record 30 of Set 5 | hambantota
# Processing Record 31 of Set 5 | lahij
# Processing Record 32 of Set 5 | san rafael del sur
# Processing Record 33 of Set 5 | kitimat
# Processing Record 34 of Set 5 | alihe
# Processing Record 35 of Set 5 | san quintin
# Processing Record 36 of Set 5 | kutulik
# Processing Record 37 of Set 5 | esperance
# Processing Record 38 of Set 5 | shingu
# Processing Record 39 of Set 5 | abu zabad
# Processing Record 40 of Set 5 | te anau
# Processing Record 41 of Set 5 | tres arroyos
# Processing Record 42 of Set 5 | wagar
# Processing Record 43 of Set 5 | santa maria
# Processing Record 44 of Set 5 | tomatlan
# Processing Record 45 of Set 5 | san joaquin
# Processing Record 46 of Set 5 | lompoc
# Processing Record 47 of Set 5 | davila
# Processing Record 48 of Set 5 | sabang
# Processing Record 49 of Set 5 | guerrero negro
# Processing Record 50 of Set 5 | shishou
# Processing Record 1 of Set 6 | coihaique
# Processing Record 2 of Set 6 | valentin gomez farias
# Processing Record 3 of Set 6 | udachnyy
# Processing Record 4 of Set 6 | saposoa
# Processing Record 5 of Set 6 | ulladulla
# Processing Record 6 of Set 6 | burgersdorp
# Processing Record 7 of Set 6 | namibe
# Processing Record 8 of Set 6 | gat
# Processing Record 9 of Set 6 | puerto narino
# Processing Record 10 of Set 6 | lorengau
# Processing Record 11 of Set 6 | chengde
# Processing Record 12 of Set 6 | cockburn town
# Processing Record 13 of Set 6 | tacoronte
# Processing Record 14 of Set 6 | moba
# Processing Record 15 of Set 6 | toora-khem
# Processing Record 16 of Set 6 | makakilo city
# Processing Record 17 of Set 6 | astara
# Processing Record 18 of Set 6 | northam
# Processing Record 19 of Set 6 | balkanabat
# Processing Record 20 of Set 6 | ilam
# Processing Record 21 of Set 6 | asau
# Processing Record 22 of Set 6 | hinton
# Processing Record 23 of Set 6 | shimoda
# Processing Record 24 of Set 6 | sorland
# Processing Record 25 of Set 6 | pathalgaon
# Processing Record 26 of Set 6 | anaconda
# Processing Record 27 of Set 6 | mwaya
# City not found. Skipping...
# Processing Record 28 of Set 6 | mawlaik
# Processing Record 29 of Set 6 | gushikawa
# Processing Record 30 of Set 6 | bethanien
# Processing Record 31 of Set 6 | okitipupa
# Processing Record 32 of Set 6 | eenhana
# Processing Record 33 of Set 6 | carstairs
# Processing Record 34 of Set 6 | zhuanghe
# Processing Record 35 of Set 6 | matara
# Processing Record 36 of Set 6 | jibuti
# Processing Record 37 of Set 6 | lekoni
# Processing Record 38 of Set 6 | suoyarvi
# Processing Record 39 of Set 6 | praia da vitoria
# Processing Record 40 of Set 6 | chuy
# Processing Record 41 of Set 6 | sagua de tanamo
# Processing Record 42 of Set 6 | barrow
# Processing Record 43 of Set 6 | zarubino
# Processing Record 44 of Set 6 | rocha
# Processing Record 45 of Set 6 | touros
# Processing Record 46 of Set 6 | lavrentiya
# Processing Record 47 of Set 6 | richards bay
# Processing Record 48 of Set 6 | angleton
# Processing Record 49 of Set 6 | darhan
# Processing Record 50 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 7 | lyubech
# Processing Record 2 of Set 7 | sidi bin nur
# Processing Record 3 of Set 7 | ca mau
# Processing Record 4 of Set 7 | yayva
# Processing Record 5 of Set 7 | flin flon
# Processing Record 6 of Set 7 | xuddur
# Processing Record 7 of Set 7 | vardo
# Processing Record 8 of Set 7 | thunder bay
# Processing Record 9 of Set 7 | kavieng
# Processing Record 10 of Set 7 | bacuit
# City not found. Skipping...
# Processing Record 11 of Set 7 | bonavista
# Processing Record 12 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 7 | tonantins
# Processing Record 14 of Set 7 | mapimi
# Processing Record 15 of Set 7 | adrar
# Processing Record 16 of Set 7 | havre
# Processing Record 17 of Set 7 | gbadolite
# Processing Record 18 of Set 7 | nakamura
# Processing Record 19 of Set 7 | komsomolskiy
# Processing Record 20 of Set 7 | maragogi
# Processing Record 21 of Set 7 | zhangye
# Processing Record 22 of Set 7 | angoche
# Processing Record 23 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 7 | the pas
# Processing Record 25 of Set 7 | ambon
# Processing Record 26 of Set 7 | banda aceh
# Processing Record 27 of Set 7 | hyeres
# Processing Record 28 of Set 7 | guaratuba
# Processing Record 29 of Set 7 | tura
# Processing Record 30 of Set 7 | eldikan
# City not found. Skipping...
# Processing Record 31 of Set 7 | ekibastuz
# Processing Record 32 of Set 7 | talnakh
# Processing Record 33 of Set 7 | peniche
# Processing Record 34 of Set 7 | ancud
# Processing Record 35 of Set 7 | gizo
# Processing Record 36 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 7 | xining
# Processing Record 38 of Set 7 | kamen-rybolov
# Processing Record 39 of Set 7 | bandarbeyla
# Processing Record 40 of Set 7 | bathsheba
# Processing Record 41 of Set 7 | kaduna
# Processing Record 42 of Set 7 | lubao
# Processing Record 43 of Set 7 | nevsehir
# Processing Record 44 of Set 7 | gornopravdinsk
# Processing Record 45 of Set 7 | valdivia
# Processing Record 46 of Set 7 | ponta delgada
# Processing Record 47 of Set 7 | kedrovyy
# Processing Record 48 of Set 7 | ribeira grande
# Processing Record 49 of Set 7 | hamilton
# Processing Record 50 of Set 7 | bereda
# Processing Record 1 of Set 8 | anloga
# Processing Record 2 of Set 8 | mangrol
# Processing Record 3 of Set 8 | itambacuri
# Processing Record 4 of Set 8 | tigil
# Processing Record 5 of Set 8 | clyde river
# Processing Record 6 of Set 8 | mae sai
# Processing Record 7 of Set 8 | anadyr
# Processing Record 8 of Set 8 | tokmak
# Processing Record 9 of Set 8 | felidhoo
# City not found. Skipping...
# Processing Record 10 of Set 8 | isakly
# Processing Record 11 of Set 8 | idar-oberstein
# Processing Record 12 of Set 8 | margate
# Processing Record 13 of Set 8 | port hardy
# Processing Record 14 of Set 8 | caravelas
# Processing Record 15 of Set 8 | umm lajj
# Processing Record 16 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 17 of Set 8 | waipawa
# Processing Record 18 of Set 8 | pio xii
# Processing Record 19 of Set 8 | san carlos de bariloche
# Processing Record 20 of Set 8 | boca raton
# Processing Record 21 of Set 8 | severo-kurilsk
# Processing Record 22 of Set 8 | adre
# Processing Record 23 of Set 8 | cap malheureux
# Processing Record 24 of Set 8 | bhinmal
# Processing Record 25 of Set 8 | turayf
# Processing Record 26 of Set 8 | begampur
# Processing Record 27 of Set 8 | zaysan
# Processing Record 28 of Set 8 | ahipara
# Processing Record 29 of Set 8 | nouakchott
# Processing Record 30 of Set 8 | arlit
# Processing Record 31 of Set 8 | mana
# Processing Record 32 of Set 8 | manavalakurichi
# Processing Record 33 of Set 8 | sao filipe
# Processing Record 34 of Set 8 | aklavik
# Processing Record 35 of Set 8 | pau brasil
# Processing Record 36 of Set 8 | coruripe
# Processing Record 37 of Set 8 | znamenskoye
# Processing Record 38 of Set 8 | vilhena
# Processing Record 39 of Set 8 | dongning
# Processing Record 40 of Set 8 | teya
# Processing Record 41 of Set 8 | tabulbah
# City not found. Skipping...
# Processing Record 42 of Set 8 | korla
# Processing Record 43 of Set 8 | sao jose da coroa grande
# Processing Record 44 of Set 8 | tigre
# Processing Record 45 of Set 8 | sur
# Processing Record 46 of Set 8 | karpathos
# Processing Record 47 of Set 8 | poiana blenchii
# Processing Record 48 of Set 8 | baykit
# Processing Record 49 of Set 8 | vaitape
# Processing Record 50 of Set 8 | meulaboh
# Processing Record 1 of Set 9 | roma
# Processing Record 2 of Set 9 | lyuban
# Processing Record 3 of Set 9 | kudat
# Processing Record 4 of Set 9 | port-gentil
# Processing Record 5 of Set 9 | koslan
# Processing Record 6 of Set 9 | knokke-heist
# Processing Record 7 of Set 9 | vengurla
# Processing Record 8 of Set 9 | qaqortoq
# Processing Record 9 of Set 9 | atherton
# Processing Record 10 of Set 9 | port lincoln
# Processing Record 11 of Set 9 | isangel
# Processing Record 12 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 9 | oranjestad
# Processing Record 14 of Set 9 | contai
# Processing Record 15 of Set 9 | omboue
# Processing Record 16 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 17 of Set 9 | yerbogachen
# Processing Record 18 of Set 9 | bonthe
# Processing Record 19 of Set 9 | altamira
# Processing Record 20 of Set 9 | dzaoudzi
# Processing Record 21 of Set 9 | hasaki
# Processing Record 22 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 23 of Set 9 | dukat
# Processing Record 24 of Set 9 | mattru
# Processing Record 25 of Set 9 | formosa
# Processing Record 26 of Set 9 | riyadh
# Processing Record 27 of Set 9 | klaksvik
# Processing Record 28 of Set 9 | ho chi minh city
# Processing Record 29 of Set 9 | gunnedah
# Processing Record 30 of Set 9 | san carlos
# Processing Record 31 of Set 9 | lixourion
# Processing Record 32 of Set 9 | boende
# Processing Record 33 of Set 9 | karratha
# Processing Record 34 of Set 9 | nuuk
# Processing Record 35 of Set 9 | beira
# Processing Record 36 of Set 9 | kazanskaya
# Processing Record 37 of Set 9 | lake city
# Processing Record 38 of Set 9 | nichinan
# Processing Record 39 of Set 9 | saint anthony
# Processing Record 40 of Set 9 | sungairaya
# Processing Record 41 of Set 9 | beeville
# Processing Record 42 of Set 9 | buta
# Processing Record 43 of Set 9 | artigas
# Processing Record 44 of Set 9 | imeni poliny osipenko
# Processing Record 45 of Set 9 | miandrivazo
# Processing Record 46 of Set 9 | redmond
# Processing Record 47 of Set 9 | villarrobledo
# Processing Record 48 of Set 9 | eresos
# Processing Record 49 of Set 9 | wundanyi
# Processing Record 50 of Set 9 | miraflores
# Processing Record 1 of Set 10 | san cristobal
# Processing Record 2 of Set 10 | rafaela
# Processing Record 3 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 10 | dalbandin
# Processing Record 5 of Set 10 | butler
# Processing Record 6 of Set 10 | bubaque
# Processing Record 7 of Set 10 | bloomingdale
# Processing Record 8 of Set 10 | minervino murge
# Processing Record 9 of Set 10 | evensk
# Processing Record 10 of Set 10 | zalari
# Processing Record 11 of Set 10 | mullovka
# Processing Record 12 of Set 10 | galesong
# Processing Record 13 of Set 10 | azad shahr
# Processing Record 14 of Set 10 | uglich
# Processing Record 15 of Set 10 | bilibino
# Processing Record 16 of Set 10 | dianopolis
# City not found. Skipping...
# Processing Record 17 of Set 10 | kemin
# Processing Record 18 of Set 10 | mitsamiouli
# Processing Record 19 of Set 10 | aykhal
# Processing Record 20 of Set 10 | shcholkine
# City not found. Skipping...
# Processing Record 21 of Set 10 | atambua
# Processing Record 22 of Set 10 | zlitan
# Processing Record 23 of Set 10 | katsuura
# Processing Record 24 of Set 10 | turochak
# Processing Record 25 of Set 10 | koupela
# Processing Record 26 of Set 10 | nishihara
# Processing Record 27 of Set 10 | lokosovo
# Processing Record 28 of Set 10 | moanda
# Processing Record 29 of Set 10 | khyriv
# Processing Record 30 of Set 10 | yumen
# Processing Record 31 of Set 10 | werda
# Processing Record 32 of Set 10 | beruni
# City not found. Skipping...
# Processing Record 33 of Set 10 | inhambane
# Processing Record 34 of Set 10 | escanaba
# Processing Record 35 of Set 10 | fortuna
# Processing Record 36 of Set 10 | baiao
# Processing Record 37 of Set 10 | calabozo
# Processing Record 38 of Set 10 | saquena
# Processing Record 39 of Set 10 | kitgum
# Processing Record 40 of Set 10 | teguldet
# Processing Record 41 of Set 10 | chake chake
# Processing Record 42 of Set 10 | acajutla
# Processing Record 43 of Set 10 | tandil
# Processing Record 44 of Set 10 | macklin
# Processing Record 45 of Set 10 | pangoa
# Processing Record 46 of Set 10 | naze
# Processing Record 47 of Set 10 | hobyo
# Processing Record 48 of Set 10 | moerai
# Processing Record 49 of Set 10 | moranbah
# Processing Record 50 of Set 10 | gorban
# Processing Record 1 of Set 11 | savannakhet
# Processing Record 2 of Set 11 | takoradi
# Processing Record 3 of Set 11 | tecpan
# Processing Record 4 of Set 11 | saint-joseph
# Processing Record 5 of Set 11 | lock haven
# Processing Record 6 of Set 11 | tecoanapa
# Processing Record 7 of Set 11 | antalaha
# Processing Record 8 of Set 11 | pisco
# Processing Record 9 of Set 11 | kaz
# Processing Record 10 of Set 11 | tazovskiy
# Processing Record 11 of Set 11 | carutapera
# Processing Record 12 of Set 11 | ulaangom
# Processing Record 13 of Set 11 | alakurtti
# Processing Record 14 of Set 11 | sabya
# Processing Record 15 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 16 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 17 of Set 11 | svetlogorsk
# Processing Record 18 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 11 | kathu
# Processing Record 20 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 21 of Set 11 | najran
# Processing Record 22 of Set 11 | piacabucu
# Processing Record 23 of Set 11 | ljungby
# Processing Record 24 of Set 11 | batemans bay
# Processing Record 25 of Set 11 | ust-nera
# Processing Record 26 of Set 11 | salinas
# Processing Record 27 of Set 11 | kalol
# Processing Record 28 of Set 11 | jati
# Processing Record 29 of Set 11 | douglas
# Processing Record 30 of Set 11 | bagdarin
# Processing Record 31 of Set 11 | yuzhno-kurilsk
# Processing Record 32 of Set 11 | kungurtug
# Processing Record 33 of Set 11 | grande prairie
# Processing Record 34 of Set 11 | vila franca do campo
# Processing Record 35 of Set 11 | catania
# Processing Record 36 of Set 11 | santa maria da boa vista
# Processing Record 37 of Set 11 | vao
# Processing Record 38 of Set 11 | vryburg
# Processing Record 39 of Set 11 | zhanaozen
# Processing Record 40 of Set 11 | martinho campos
# Processing Record 41 of Set 11 | zuenoula
# Processing Record 42 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 11 | rock springs
# Processing Record 44 of Set 11 | zhanakorgan
# Processing Record 45 of Set 11 | olafsvik
# Processing Record 46 of Set 11 | lubango
# Processing Record 47 of Set 11 | kamaishi
# Processing Record 48 of Set 11 | alofi
# Processing Record 49 of Set 11 | santa vitoria do palmar
# Processing Record 50 of Set 11 | svecha
# Processing Record 1 of Set 12 | ola
# Processing Record 2 of Set 12 | juneau
# Processing Record 3 of Set 12 | roald
# Processing Record 4 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 5 of Set 12 | krasnyy profintern
# Processing Record 6 of Set 12 | emerald
# Processing Record 7 of Set 12 | bom jesus
# Processing Record 8 of Set 12 | opuwo
# Processing Record 9 of Set 12 | syedove
# Processing Record 10 of Set 12 | el alto
# Processing Record 11 of Set 12 | seydi
# Processing Record 12 of Set 12 | abrau-dyurso
# Processing Record 13 of Set 12 | qandala
# Processing Record 14 of Set 12 | male
# Processing Record 15 of Set 12 | tonstad
# Processing Record 16 of Set 12 | lasa
# Processing Record 17 of Set 12 | mujiayingzi
# Processing Record 18 of Set 12 | crestview
# Processing Record 19 of Set 12 | ruteng
# Processing Record 20 of Set 12 | beringovskiy
# Processing Record 21 of Set 12 | kupang
# Processing Record 22 of Set 12 | afyonkarahisar
# Processing Record 23 of Set 12 | seoul
# Processing Record 24 of Set 12 | santa rosa
# Processing Record 25 of Set 12 | passo fundo
# Processing Record 26 of Set 12 | gorodishche
# Processing Record 27 of Set 12 | daoukro
# Processing Record 28 of Set 12 | itupiranga
# Processing Record 29 of Set 12 | quelimane
# Processing Record 30 of Set 12 | puerto del rosario
# Processing Record 31 of Set 12 | george
# Processing Record 32 of Set 12 | ilhabela
# Processing Record 33 of Set 12 | ketchikan
# Processing Record 34 of Set 12 | bilma
# Processing Record 35 of Set 12 | puerto leguizamo
# Processing Record 36 of Set 12 | west richland
# Processing Record 37 of Set 12 | mizdah
# Processing Record 38 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 39 of Set 12 | kieta
# Processing Record 40 of Set 12 | alice springs
# Processing Record 41 of Set 12 | cheremukhovo
# Processing Record 42 of Set 12 | belmonte
# Processing Record 43 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 44 of Set 12 | stromness
# Processing Record 45 of Set 12 | cabedelo
# Processing Record 46 of Set 12 | khandyga
# Processing Record 47 of Set 12 | oksfjord
# Processing Record 48 of Set 12 | maun
# Processing Record 49 of Set 12 | san andres
# Processing Record 50 of Set 12 | clarksburg
# Processing Record 1 of Set 13 | biloela
# Processing Record 2 of Set 13 | guaruja
# Processing Record 3 of Set 13 | port-de-bouc
# Processing Record 4 of Set 13 | puerto parra
# Processing Record 5 of Set 13 | fallon
# Processing Record 6 of Set 13 | constantine
# Processing Record 7 of Set 13 | balgazyn
# Processing Record 8 of Set 13 | gouyave
# Processing Record 9 of Set 13 | inyonga
# Processing Record 10 of Set 13 | maceio
# Processing Record 11 of Set 13 | zhigansk
# Processing Record 12 of Set 13 | palmer
# Processing Record 13 of Set 13 | rio tercero
# Processing Record 14 of Set 13 | guia de isora
# Processing Record 15 of Set 13 | nazilli
# Processing Record 16 of Set 13 | alekseyevka
# Processing Record 17 of Set 13 | heyang
# Processing Record 18 of Set 13 | lincoln
# Processing Record 19 of Set 13 | rosario
# Processing Record 20 of Set 13 | shubarshi
# Processing Record 21 of Set 13 | ampanihy
# Processing Record 22 of Set 13 | monticello
# Processing Record 23 of Set 13 | chimbote
# Processing Record 24 of Set 13 | ulaanbaatar
# Processing Record 25 of Set 13 | comodoro rivadavia
# Processing Record 26 of Set 13 | hunterville
# Processing Record 27 of Set 13 | flinders
# Processing Record 28 of Set 13 | buritizeiro
# Processing Record 29 of Set 13 | grootfontein
# Processing Record 30 of Set 13 | portland
# Processing Record 31 of Set 13 | hay river
# Processing Record 32 of Set 13 | guangyuan
# Processing Record 33 of Set 13 | okhotsk
# Processing Record 34 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 13 | yining
# Processing Record 36 of Set 13 | usoke
# Processing Record 37 of Set 13 | benalla
# Processing Record 38 of Set 13 | haileybury
# Processing Record 39 of Set 13 | boali
# Processing Record 40 of Set 13 | cayenne
# Processing Record 41 of Set 13 | nanortalik
# Processing Record 42 of Set 13 | ucluelet
# Processing Record 43 of Set 13 | chumikan
# Processing Record 44 of Set 13 | teocelo
# Processing Record 45 of Set 13 | hanmer springs
# Processing Record 46 of Set 13 | tabuk
# Processing Record 47 of Set 13 | kimberley
# Processing Record 48 of Set 13 | kabakovo
# Processing Record 49 of Set 13 | tautira
# Processing Record 50 of Set 13 | rio gallegos
# Processing Record 1 of Set 14 | bonfim
# Processing Record 2 of Set 14 | aporawan
# City not found. Skipping...
# Processing Record 3 of Set 14 | haapiti
# Processing Record 4 of Set 14 | amapa
# Processing Record 5 of Set 14 | ouesso
# Processing Record 6 of Set 14 | tuatapere
# Processing Record 7 of Set 14 | sayanskiy
# City not found. Skipping...
# Processing Record 8 of Set 14 | xiongshi
# City not found. Skipping...
# Processing Record 9 of Set 14 | pangnirtung
# Processing Record 10 of Set 14 | radishchevo
# Processing Record 11 of Set 14 | pilar
# Processing Record 12 of Set 14 | mehamn
# Processing Record 13 of Set 14 | djibo
# Processing Record 14 of Set 14 | halifax
# Processing Record 15 of Set 14 | benghazi
# Processing Record 16 of Set 14 | broome
# Processing Record 17 of Set 14 | san lawrenz
# Processing Record 18 of Set 14 | smirnykh
# Processing Record 19 of Set 14 | loukhi
# Processing Record 20 of Set 14 | chipiona
# Processing Record 21 of Set 14 | turukhansk
# Processing Record 22 of Set 14 | westport
# Processing Record 23 of Set 14 | conway
# Processing Record 24 of Set 14 | kenai
# Processing Record 25 of Set 14 | christchurch
# Processing Record 26 of Set 14 | katangli
# Processing Record 27 of Set 14 | sakakah
# Processing Record 28 of Set 14 | san borja
# Processing Record 29 of Set 14 | alpnach
# Processing Record 30 of Set 14 | bejar
# Processing Record 31 of Set 14 | deputatskiy
# Processing Record 32 of Set 14 | alcaniz
# Processing Record 33 of Set 14 | morehead
# Processing Record 34 of Set 14 | panjakent
# Processing Record 35 of Set 14 | lakes entrance
# Processing Record 36 of Set 14 | veraval
# Processing Record 37 of Set 14 | lucea
# Processing Record 38 of Set 14 | mareeba
# Processing Record 39 of Set 14 | nortelandia
# Processing Record 40 of Set 14 | leopold
# Processing Record 41 of Set 14 | banepa
# Processing Record 42 of Set 14 | sao lourenco
# Processing Record 43 of Set 14 | reo
# Processing Record 44 of Set 14 | semirom
# Processing Record 45 of Set 14 | taraclia
# Processing Record 46 of Set 14 | verkhoyansk
# Processing Record 47 of Set 14 | gulshat
# City not found. Skipping...
# Processing Record 48 of Set 14 | port augusta
# Processing Record 49 of Set 14 | bani
# Processing Record 50 of Set 14 | monrovia
# Processing Record 1 of Set 15 | baruun-urt
# Processing Record 2 of Set 15 | segezha
# Processing Record 3 of Set 15 | sokolovo
# Processing Record 4 of Set 15 | jurm
# Processing Record 5 of Set 15 | naerbo
# Processing Record 6 of Set 15 | marawi
# Processing Record 7 of Set 15 | at-bashi
# Processing Record 8 of Set 15 | lagoa
# Processing Record 9 of Set 15 | vavuniya
# Processing Record 10 of Set 15 | brokopondo
# Processing Record 11 of Set 15 | kindu
# Processing Record 12 of Set 15 | ciras
# City not found. Skipping...
# Processing Record 13 of Set 15 | vallenar
# Processing Record 14 of Set 15 | thai binh
# Processing Record 15 of Set 15 | yunyang
# Processing Record 16 of Set 15 | hanna
# Processing Record 17 of Set 15 | talara
# Processing Record 18 of Set 15 | grand gaube
# Processing Record 19 of Set 15 | lipin bor
# Processing Record 20 of Set 15 | saint-francois
# Processing Record 21 of Set 15 | vidim
# Processing Record 22 of Set 15 | bitung
# Processing Record 23 of Set 15 | magdagachi
# Processing Record 24 of Set 15 | yulara
# Processing Record 25 of Set 15 | baley
# Processing Record 26 of Set 15 | batsfjord
# Processing Record 27 of Set 15 | rochegda
# Processing Record 28 of Set 15 | sobolevo
# Processing Record 29 of Set 15 | guanica
# Processing Record 30 of Set 15 | anori
# Processing Record 31 of Set 15 | luau
# Processing Record 32 of Set 15 | blois
# Processing Record 33 of Set 15 | markivka
# Processing Record 34 of Set 15 | mabaruma
# Processing Record 35 of Set 15 | dicabisagan
# Processing Record 36 of Set 15 | jodiya
# Processing Record 37 of Set 15 | zhaozhou
# Processing Record 38 of Set 15 | kushima
# Processing Record 39 of Set 15 | juli
# Processing Record 40 of Set 15 | port moresby
# Processing Record 41 of Set 15 | manggar
# Processing Record 42 of Set 15 | hovd
# Processing Record 43 of Set 15 | domoni
# Processing Record 44 of Set 15 | rio claro
# Processing Record 45 of Set 15 | kapit
# Processing Record 46 of Set 15 | wana
# Processing Record 47 of Set 15 | mohan
# Processing Record 48 of Set 15 | rindal
# Processing Record 49 of Set 15 | indramayu
# Processing Record 50 of Set 15 | mus
# Processing Record 1 of Set 16 | dudinka
# Processing Record 2 of Set 16 | sao joao da barra
# Processing Record 3 of Set 16 | aviles
# Processing Record 4 of Set 16 | payo
# Processing Record 5 of Set 16 | basco
# Processing Record 6 of Set 16 | bandar penggaram
# City not found. Skipping...
# Processing Record 7 of Set 16 | verkhnyaya inta
# Processing Record 8 of Set 16 | thinadhoo
# Processing Record 9 of Set 16 | marihatag
# Processing Record 10 of Set 16 | ukiah
# Processing Record 11 of Set 16 | rantepao
# Processing Record 12 of Set 16 | malinyi
# Processing Record 13 of Set 16 | havoysund
# Processing Record 14 of Set 16 | muros
# Processing Record 15 of Set 16 | krasnoselkup
# Processing Record 16 of Set 16 | sorong
# Processing Record 17 of Set 16 | lazaro cardenas
# Processing Record 18 of Set 16 | nizhneudinsk
# Processing Record 19 of Set 16 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 16 | beloha
# Processing Record 21 of Set 16 | mkushi
# Processing Record 22 of Set 16 | kalispell
# Processing Record 23 of Set 16 | sant feliu de guixols
# Processing Record 24 of Set 16 | xiuyan
# Processing Record 25 of Set 16 | bosaso
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check number of cities
len(city_data)
# Out:
# 719

# %%
# Convert array of dictionaries to Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Peto      MX  20.1333  -88.9167     71.17       100         100
# 1      Albany      US  42.6001  -73.9662     32.07        85           3
# 2      Dikson      RU  73.5069   80.5464     -8.93        95          95
# 3      Hobart      AU -42.8794  147.3294     59.11        76          75
# 4    Hermanus      ZA -34.4187   19.2345     67.89        73          95
# 5     Rikitea      PF -23.1203 -134.9692     73.42        67         100
# 6       Bluff      NZ -46.6000  168.3333     51.82        82         100
# 7      Avarua      CK -21.2078 -159.7750     77.05        78          20
# 8  Hervey Bay      AU -25.2986  152.8535     82.04        60           0
# 9    Cidreira      BR -30.1811  -50.2056     61.00        76           0
#
#    Wind Speed Current Description
# 0        1.48     overcast clouds
# 1        3.76           clear sky
# 2        6.02     overcast clouds
# 3        1.01       broken clouds
# 4       17.67     overcast clouds
# 5       10.38     overcast clouds
# 6        3.06     overcast clouds
# 7        6.91          few clouds
# 8       10.69           clear sky
# 9        6.49           clear sky

# %%
# Create output CSV file
output_data_file = "WeatherPy_Database.csv"
# Export City_Data DataFrame into CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
